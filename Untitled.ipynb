# %%
import urllib2
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
def scrape_list(site):
    source_code = requests.get(site)
    soup = BeautifulSoup(source_code.text,'html.parser')
    table = soup.find('span', id='S.26P_500_Component_Stocks').parent.find_next_sibling('table')
    names = list()
    urls = list()
    ids = list()
    for row in table.findAll('tr'):
        col = row.findAll('td')
        if len(col) > 0:
            link = "https://en.wikipedia.org" + col[1].find('a').get('href')
            id1 = col[1].find('a').get('href')[6:]
            urls.append(link)
            name =  str(col[1].string.strip())
            ids.append(id1)
            names.append(name)
    df = pd.concat([pd.Series(names), pd.Series(urls), pd.Series(ids)], axis=1, keys=['names', 'urls','ids'])
    return df

# %%
def get_pageid(name):
    url = 'http://en.wikipedia.org/w/api.php?action=query&prop=info&format=json&titles=' + name
    resp = requests.get(url)
    data = resp.json()
    try:
        return data['query']['pages'].itervalues().next()['pageid']
    except:
        return None

# %%
if __name__ == '__main__':
    site = "https://en.wikipedia.org/w/index.php?title=List_of_S%26P_500_companies&oldid=697200065"
    df = scrape_list(site)
    print df

# %%
df
# Out:
#                              names  \
# 0                       3M Company
# 1              Abbott Laboratories
# 2                           AbbVie
# 3                    Accenture plc
# 4                      ACE Limited
# 5              Activision Blizzard
# 6                Adobe Systems Inc
# 7                         ADT Corp
# 8               Advance Auto Parts
# 9                         AES Corp
# 10                       Aetna Inc
# 11                       AFLAC Inc
# 12   Affiliated Managers Group Inc
# 13        Agilent Technologies Inc
# 14              AGL Resources Inc.
# 15    Air Products & Chemicals Inc
# 16                      Airgas Inc
# 17         Akamai Technologies Inc
# 18                       Alcoa Inc
# 19                    Allergan plc
# 20         Alexion Pharmaceuticals
# 21                        Allegion
# 22           Alliance Data Systems
# 23                   Allstate Corp
# 24            Alphabet Inc Class A
# 25            Alphabet Inc Class C
# 26                Altria Group Inc
# 27                  Amazon.com Inc
# 28                     Ameren Corp
# 29         American Airlines Group
# ..                             ...
# 474                      Visa Inc.
# 475           Vornado Realty Trust
# 476               Vulcan Materials
# 477                Wal-Mart Stores
# 478       Walgreens Boots Alliance
# 479        The Walt Disney Company
# 480          Waste Management Inc.
# 481             Waters Corporation
# 482                    Anthem Inc.
# 483                    Wells Fargo
# 484                 Welltower Inc.
# 485                Western Digital
# 486               Western Union Co
# 487             Weyerhaeuser Corp.
# 488                Whirlpool Corp.
# 489             Whole Foods Market
# 490                  Williams Cos.
# 491   Wisconsin Energy Corporation
# 492              Wyndham Worldwide
# 493               Wynn Resorts Ltd
# 494                Xcel Energy Inc
# 495                    Xerox Corp.
# 496                     Xilinx Inc
# 497                     XL Capital
# 498                     Xylem Inc.
# 499                     Yahoo Inc.
# 500                Yum! Brands Inc
# 501         Zimmer Biomet Holdings
# 502                  Zions Bancorp
# 503                         Zoetis
#
#                                                   urls  \
# 490        https://en.wikipedia.org/wiki/Williams_Cos.
# 491  https://en.wikipedia.org/wiki/Wisconsin_Energy...
# 492    https://en.wikipedia.org/wiki/Wyndham_Worldwide
# 493     https://en.wikipedia.org/wiki/Wynn_Resorts_Ltd
# 494      https://en.wikipedia.org/wiki/Xcel_Energy_Inc
# 495          https://en.wikipedia.org/wiki/Xerox_Corp.
# 496           https://en.wikipedia.org/wiki/Xilinx_Inc
# 497           https://en.wikipedia.org/wiki/XL_Capital
# 498           https://en.wikipedia.org/wiki/Xylem_Inc.
# 499           https://en.wikipedia.org/wiki/Yahoo_Inc.
# 500      https://en.wikipedia.org/wiki/Yum!_Brands_Inc
# 501      https://en.wikipedia.org/wiki/Zimmer_Holdings
# 502        https://en.wikipedia.org/wiki/Zions_Bancorp
# 503               https://en.wikipedia.org/wiki/Zoetis
#
#                                 ids
# 0                                3M
# 1               Abbott_Laboratories
# 2                            AbbVie
# 3                     Accenture_plc
# 4                       ACE_Limited
# 5               Activision_Blizzard
# 6                 Adobe_Systems_Inc
# 7                          ADT_Corp
# 8                Advance_Auto_Parts
# 9                          AES_Corp
# 10                        Aetna_Inc
# 11                        AFLAC_Inc
# 12    Affiliated_Managers_Group_Inc
# 13         Agilent_Technologies_Inc
# 14               AGL_Resources_Inc.
# 15   Air_Products_%26_Chemicals_Inc
# 16                       Airgas_Inc
# 17          Akamai_Technologies_Inc
# 18                        Alcoa_Inc
# 19                         Allergan
# 20          Alexion_Pharmaceuticals
# 21                         Allegion
# 22            Alliance_Data_Systems
# 23                    Allstate_Corp
# 24             Alphabet_Inc_Class_A
# 25             Alphabet_Inc_Class_C
# 26                 Altria_Group_Inc
# 27                   Amazon.com_Inc
# 28                      Ameren_Corp
# 29          American_Airlines_Group
# ..                              ...
# 474                       Visa_Inc.
# 475            Vornado_Realty_Trust
# 476                Vulcan_Materials
# 477                 Wal-Mart_Stores
# 478        Walgreens_Boots_Alliance
# 479         The_Walt_Disney_Company
# 480           Waste_Management_Inc.
# 481              Waters_Corporation
# 482                     Anthem_Inc.
# 483                     Wells_Fargo
# 484                  Welltower_Inc.
# 485                 Western_Digital
# 486                Western_Union_Co
# 487              Weyerhaeuser_Corp.
# 488                 Whirlpool_Corp.
# 489              Whole_Foods_Market
# 490                   Williams_Cos.
# 491    Wisconsin_Energy_Corporation
# 492               Wyndham_Worldwide
# 493                Wynn_Resorts_Ltd
# 494                 Xcel_Energy_Inc
# 495                     Xerox_Corp.
# 496                      Xilinx_Inc
# 497                      XL_Capital
# 498                      Xylem_Inc.
# 499                      Yahoo_Inc.
# 500                 Yum!_Brands_Inc
# 501                 Zimmer_Holdings
# 502                   Zions_Bancorp
# 503                          Zoetis
#
# [504 rows x 3 columns]
