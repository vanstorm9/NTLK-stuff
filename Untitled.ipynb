# %%
import urllib2
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
def scrape_list(site):
    source_code = requests.get(site)
    soup = BeautifulSoup(source_code.text,'html.parser')
    table = soup.find('span', id='S.26P_500_Component_Stocks').parent.find_next_sibling('table')
    names = list()
    urls = list()
    ids = list()
    for row in table.findAll('tr'):
        col = row.findAll('td')
        if len(col) > 0:
            link = "https://en.wikipedia.org" + col[1].find('a').get('href')
            id1 = col[1].find('a').get('href')[6:]
            urls.append(link)
            name =  str(col[1].string.strip())
            ids.append(id1)
            names.append(name)
    df = pd.concat([pd.Series(names), pd.Series(urls), pd.Series(ids)], axis=1, keys=['names', 'urls','ids'])
    return df

# %%
def get_pageid(name):
    
    r  = requests.get(name)
    data = r.text
    soup = BeautifulSoup(data) 
    s1 = soup.find_all('script')[1]
    try:
        string = re.search('wgArticleId":(\d+)', str(s1.string)).group()
    except:
        f = unicode.join(u'',map(unicode,s1.string))
        string = re.search('wgArticleId":(\d+)', f).group()
        return int(re.search('\d+', string).group())
    return int(re.search('\d+', string).group())

# %%
if __name__ == '__main__':
    site = "https://en.wikipedia.org/w/index.php?title=List_of_S%26P_500_companies&oldid=697200065"
    df = scrape_list(site)
    #print df

# %%
df
# Out:
#                              names  \
# 0                       3M Company
# 1              Abbott Laboratories
# 2                           AbbVie
# 3                    Accenture plc
# 4                      ACE Limited
# 5              Activision Blizzard
# 6                Adobe Systems Inc
# 7                         ADT Corp
# 8               Advance Auto Parts
# 9                         AES Corp
# 10                       Aetna Inc
# 11                       AFLAC Inc
# 12   Affiliated Managers Group Inc
# 13        Agilent Technologies Inc
# 14              AGL Resources Inc.
# 15    Air Products & Chemicals Inc
# 16                      Airgas Inc
# 17         Akamai Technologies Inc
# 18                       Alcoa Inc
# 19                    Allergan plc
# 20         Alexion Pharmaceuticals
# 21                        Allegion
# 22           Alliance Data Systems
# 23                   Allstate Corp
# 24            Alphabet Inc Class A
# ...

# %%
df['pageid'] = df['urls'].apply(get_pageid)

# %%
df
# Out:
#                              names  \
# 0                       3M Company
# 1              Abbott Laboratories
# 2                           AbbVie
# 3                    Accenture plc
# 4                      ACE Limited
# 5              Activision Blizzard
# 6                Adobe Systems Inc
# 7                         ADT Corp
# 8               Advance Auto Parts
# 9                         AES Corp
# 10                       Aetna Inc
# 11                       AFLAC Inc
# 12   Affiliated Managers Group Inc
# 13        Agilent Technologies Inc
# 14              AGL Resources Inc.
# 15    Air Products & Chemicals Inc
# 16                      Airgas Inc
# 17         Akamai Technologies Inc
# 18                       Alcoa Inc
# 19                    Allergan plc
# 20         Alexion Pharmaceuticals
# 21                        Allegion
# 22           Alliance Data Systems
# 23                   Allstate Corp
# 24            Alphabet Inc Class A
# ...

# %%
import wikipedia

# %%
def get_content(page):
    try:
        page = wikipedia.page(pageid=page)
    except:
          return 'NA'
    return page.content

# %%
df['content'] = df['pageid'].apply(get_content)

# %%
df[df['content'] == 'NA']
# Out:
#                            names  \
# 118  Columbia Pipeline Group Inc
# 129                    CSRA Inc.
# 174     Essex Property Trust Inc
# 296                  Westrock Co
#
#                                                   urls  \
# 118  https://en.wikipedia.org/w/index.php?title=Col...
# 129  https://en.wikipedia.org/w/index.php?title=CSR...
# 174  https://en.wikipedia.org/w/index.php?title=Ess...
# 296  https://en.wikipedia.org/w/index.php?title=Wes...
#
#                                                    ids  pageid content
# 118  ex.php?title=Columbia_Pipeline_Group_Inc&actio...       0      NA
# 129       ex.php?title=CSRA_Inc.&action=edit&redlink=1       0      NA
# 174  ex.php?title=Essex_Property_Trust_Inc&action=e...       0      NA
# 296     ex.php?title=Westrock_Co&action=edit&redlink=1       0      NA

# %%
df = df[df.content != 'NA']

# %%
df.to_csv('companiesSP_raw.csv',  encoding='utf-8')

# %%
def content_by_name(name):
    index = df[df['names']=='Yahoo Inc.'].index.tolist()
    
    cont = df['content'][index]
    print type(cont)
    return cont

# %%
s= content_by_name('Yahoo Inc.')
# Out:
# <class 'pandas.core.series.Series'>

# %%
s
# Out:
# 499    Yahoo Inc. (styled as Yahoo!) is an American m...
# Name: content, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
df['content'][499]
# Out:
# u'Yahoo Inc. (styled as Yahoo!) is an American multinational technology company headquartered in Sunnyvale, California. It is globally known for its Web portal, search engine Yahoo! Search, and related services, including Yahoo! Directory, Yahoo! Mail, Yahoo! News, Yahoo! Finance, Yahoo! Groups, Yahoo! Answers, advertising, online mapping, video sharing, fantasy sports and its social media website. It is one of the most popular sites in the United States. According to third-party web analytics providers, Alexa and SimilarWeb, Yahoo! is the highest-read news and media website, with over 7 billion readers per month, being the fourth most visited website globally, as of June 2015. According to news sources, roughly 700 million people visit Yahoo websites every month. Yahoo itself claims it attracts "more than half a billion consumers every month in more than 30 languages."\nYahoo was founded by Jerry Yang and David Filo in January 1994 and was incorporated on March 2, 1995. Marissa Maye
# ...

# %%
type(df['content'][0])
# Out:
# unicode

# %%
df[df['names']=='Yahoo Inc.'].index.tolist()
# Out:
# [499]

# %%
a = 'CSRA Inc.'

# %%
df[df.names==a]
# Out:
# Empty DataFrame
# Columns: [names, urls, ids, pageid, content]
# Index: []
